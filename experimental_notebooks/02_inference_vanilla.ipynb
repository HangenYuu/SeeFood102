# %%
import torch
import timm
from torchvision.datasets import Food101
from torch.utils.data import DataLoader
from tqdm import tqdm
import torchmetrics

# %%
checkpoint = torch.load("models/levit_256.fb_dist_in1k/checkpoints.ckpt")
print(checkpoint.keys())
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers', 'MixedPrecisionPlugin'])

# %%
state_dict = {}
for key in checkpoint["state_dict"]:
    new_key = key.replace('model.','')
    state_dict[new_key] = checkpoint["state_dict"][key]
state_dict.keys()
# Out:
# dict_keys(['stem.conv1.linear.weight', 'stem.conv1.bn.weight', 'stem.conv1.bn.bias', 'stem.conv1.bn.running_mean', 'stem.conv1.bn.running_var', 'stem.conv1.bn.num_batches_tracked', 'stem.conv2.linear.weight', 'stem.conv2.bn.weight', 'stem.conv2.bn.bias', 'stem.conv2.bn.running_mean', 'stem.conv2.bn.running_var', 'stem.conv2.bn.num_batches_tracked', 'stem.conv3.linear.weight', 'stem.conv3.bn.weight', 'stem.conv3.bn.bias', 'stem.conv3.bn.running_mean', 'stem.conv3.bn.running_var', 'stem.conv3.bn.num_batches_tracked', 'stem.conv4.linear.weight', 'stem.conv4.bn.weight', 'stem.conv4.bn.bias', 'stem.conv4.bn.running_mean', 'stem.conv4.bn.running_var', 'stem.conv4.bn.num_batches_tracked', 'stages.0.blocks.0.attn.attention_biases', 'stages.0.blocks.0.attn.qkv.linear.weight', 'stages.0.blocks.0.attn.qkv.bn.weight', 'stages.0.blocks.0.attn.qkv.bn.bias', 'stages.0.blocks.0.attn.qkv.bn.running_mean', 'stages.0.blocks.0.attn.qkv.bn.running_var', 'stages.0.blocks.0.attn.qkv.bn.num_batches_tracked', 'stages.0.blocks.0.attn.proj.ln.linear.weight', 'stages.0.blocks.0.attn.proj.ln.bn.weight', 'stages.0.blocks.0.attn.proj.ln.bn.bias', 'stages.0.blocks.0.attn.proj.ln.bn.running_mean', 'stages.0.blocks.0.attn.proj.ln.bn.running_var', 'stages.0.blocks.0.attn.proj.ln.bn.num_batches_tracked', 'stages.0.blocks.0.mlp.ln1.linear.weight', 'stages.0.blocks.0.mlp.ln1.bn.weight', 'stages.0.blocks.0.mlp.ln1.bn.bias', 'stages.0.blocks.0.mlp.ln1.bn.running_mean', 'stages.0.blocks.0.mlp.ln1.bn.running_var', 'stages.0.blocks.0.mlp.ln1.bn.num_batches_tracked', 'stages.0.blocks.0.mlp.ln2.linear.weight', 'stages.0.blocks.0.mlp.ln2.bn.weight', 'stages.0.blocks.0.mlp.ln2.bn.bias', 'stages.0.blocks.0.mlp.ln2.bn.running_mean', 'stages.0.blocks.0.mlp.ln2.bn.running_var', 'stages.0.blocks.0.mlp.ln2.bn.num_batches_tracked', 'stages.0.blocks.1.attn.attention_biases', 'stages.0.blocks.1.attn.qkv.linear.weight', 'stages.0.blocks.1.attn.qkv.bn.weight', 'stages.0.blocks.1.attn.qkv.bn.bias', 'stages.0.blocks.1.attn.qkv.bn.running_mean', 'stages.0.blocks.1.attn.qkv.bn.running_var', 'stages.0.blocks.1.attn.qkv.bn.num_batches_tracked', 'stages.0.blocks.1.attn.proj.ln.linear.weight', 'stages.0.blocks.1.attn.proj.ln.bn.weight', 'stages.0.blocks.1.attn.proj.ln.bn.bias', 'stages.0.blocks.1.attn.proj.ln.bn.running_mean', 'stages.0.blocks.1.attn.proj.ln.bn.running_var', 'stages.0.blocks.1.attn.proj.ln.bn.num_batches_tracked', 'stages.0.blocks.1.mlp.ln1.linear.weight', 'stages.0.blocks.1.mlp.ln1.bn.weight', 'stages.0.blocks.1.mlp.ln1.bn.bias', 'stages.0.blocks.1.mlp.ln1.bn.running_mean', 'stages.0.blocks.1.mlp.ln1.bn.running_var', 'stages.0.blocks.1.mlp.ln1.bn.num_batches_tracked', 'stages.0.blocks.1.mlp.ln2.linear.weight', 'stages.0.blocks.1.mlp.ln2.bn.weight', 'stages.0.blocks.1.mlp.ln2.bn.bias', 'stages.0.blocks.1.mlp.ln2.bn.running_mean', 'stages.0.blocks.1.mlp.ln2.bn.running_var', 'stages.0.blocks.1.mlp.ln2.bn.num_batches_tracked', 'stages.0.blocks.2.attn.attention_biases', 'stages.0.blocks.2.attn.qkv.linear.weight', 'stages.0.blocks.2.attn.qkv.bn.weight', 'stages.0.blocks.2.attn.qkv.bn.bias', 'stages.0.blocks.2.attn.qkv.bn.running_mean', 'stages.0.blocks.2.attn.qkv.bn.running_var', 'stages.0.blocks.2.attn.qkv.bn.num_batches_tracked', 'stages.0.blocks.2.attn.proj.ln.linear.weight', 'stages.0.blocks.2.attn.proj.ln.bn.weight', 'stages.0.blocks.2.attn.proj.ln.bn.bias', 'stages.0.blocks.2.attn.proj.ln.bn.running_mean', 'stages.0.blocks.2.attn.proj.ln.bn.running_var', 'stages.0.blocks.2.attn.proj.ln.bn.num_batches_tracked', 'stages.0.blocks.2.mlp.ln1.linear.weight', 'stages.0.blocks.2.mlp.ln1.bn.weight', 'stages.0.blocks.2.mlp.ln1.bn.bias', 'stages.0.blocks.2.mlp.ln1.bn.running_mean', 'stages.0.blocks.2.mlp.ln1.bn.running_var', 'stages.0.blocks.2.mlp.ln1.bn.num_batches_tracked', 'stages.0.blocks.2.mlp.ln2.linear.weight', 'stages.0.blocks.2.mlp.ln2.bn.weight', 'stages.0.blocks.2.mlp.ln2.bn.bias', 'stages.0.blocks.2.mlp.ln2.bn.running_mean', 'stages.0.blocks.2.mlp.ln2.bn.running_var', 'sta ...

# %%
model = timm.create_model("models/levit_256.fb_dist_in1k", pretrained=False, num_classes=101)
model.load_state_dict(state_dict)
model.cpu()
model
# Out:
# LevitDistilled(
#   (stem): Stem16(
#     (conv1): ConvNorm(
#       (linear): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act1): Hardswish()
#     (conv2): ConvNorm(
#       (linear): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act2): Hardswish()
#     (conv3): ConvNorm(
#       (linear): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act3): Hardswish()
#     (conv4): ConvNorm(
#       (linear): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (stages): Sequential(
#     (0): LevitStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=256, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=256, out_features=256, bias=False)
#                 (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=512, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#         (1): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=256, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=256, out_features=256, bias=False)
#                 (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=512, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#         (2): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=256, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=256, out_features=256, bias=False)
#                 (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=512, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#         (3): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=256, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=256, out_features=256, bias=False)
#                 (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=256, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=512, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#       )
#     )
#     (1): LevitStage(
#       (downsample): LevitDownsample(
#         (attn_downsample): AttentionDownsample(
#           (kv): LinearNorm(
#             (linear): Linear(in_features=256, out_features=1280, bias=False)
#             (bn): BatchNorm1d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (q): Sequential(
#             (down): Downsample()
#             (ln): LinearNorm(
#               (linear): Linear(in_features=256, out_features=256, bias=False)
#               (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (proj): Sequential(
#             (act): Hardswish()
#             (ln): LinearNorm(
#               (linear): Linear(in_features=1024, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=384, out_features=768, bias=False)
#             (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.0, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=768, out_features=384, bias=False)
#             (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path): Identity()
#       )
#       (blocks): Sequential(
#         (0): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=384, out_features=768, bias=False)
#               (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=384, out_features=384, bias=False)
#                 (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=768, bias=False)
#               (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=768, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#         (1): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=384, out_features=768, bias=False)
#               (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=384, out_features=384, bias=False)
#                 (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=768, bias=False)
#               (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=768, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#         (2): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=384, out_features=768, bias=False)
#               (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=384, out_features=384, bias=False)
#                 (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=768, bias=False)
#               (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=768, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#         (3): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=384, out_features=768, bias=False)
#               (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=384, out_features=384, bias=False)
#                 (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=384, out_features=768, bias=False)
#               (bn): BatchNorm1d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=768, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#       )
#     )
#     (2): LevitStage(
#       (downsample): LevitDownsample(
#         (attn_downsample): AttentionDownsample(
#           (kv): LinearNorm(
#             (linear): Linear(in_features=384, out_features=1920, bias=False)
#             (bn): BatchNorm1d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (q): Sequential(
#             (down): Downsample()
#             (ln): LinearNorm(
#               (linear): Linear(in_features=384, out_features=384, bias=False)
#               (bn): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (proj): Sequential(
#             (act): Hardswish()
#             (ln): LinearNorm(
#               (linear): Linear(in_features=1536, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (mlp): LevitMlp(
#           (ln1): LinearNorm(
#             (linear): Linear(in_features=512, out_features=1024, bias=False)
#             (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act): Hardswish()
#           (drop): Dropout(p=0.0, inplace=False)
#           (ln2): LinearNorm(
#             (linear): Linear(in_features=1024, out_features=512, bias=False)
#             (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (drop_path): Identity()
#       )
#       (blocks): Sequential(
#         (0): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=512, out_features=1024, bias=False)
#               (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=512, out_features=512, bias=False)
#                 (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=512, out_features=1024, bias=False)
#               (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=1024, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#         (1): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=512, out_features=1024, bias=False)
#               (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=512, out_features=512, bias=False)
#                 (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=512, out_features=1024, bias=False)
#               (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=1024, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#         (2): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=512, out_features=1024, bias=False)
#               (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=512, out_features=512, bias=False)
#                 (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=512, out_features=1024, bias=False)
#               (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=1024, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#         (3): LevitBlock(
#           (attn): Attention(
#             (qkv): LinearNorm(
#               (linear): Linear(in_features=512, out_features=1024, bias=False)
#               (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (proj): Sequential(
#               (act): Hardswish()
#               (ln): LinearNorm(
#                 (linear): Linear(in_features=512, out_features=512, bias=False)
#                 (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (drop_path1): Identity()
#           (mlp): LevitMlp(
#             (ln1): LinearNorm(
#               (linear): Linear(in_features=512, out_features=1024, bias=False)
#               (bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): Hardswish()
#             (drop): Dropout(p=0.0, inplace=False)
#             (ln2): LinearNorm(
#               (linear): Linear(in_features=1024, out_features=512, bias=False)
#               (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (drop_path2): Identity()
#         )
#       )
#     )
#   )
#   (head): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=101, bias=True)
#   )
#   (head_dist): NormLinear(
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (drop): Dropout(p=0.0, inplace=False)
#     (linear): Linear(in_features=512, out_features=101, bias=True)
#   )
# )

# %%
data_cfg = timm.data.resolve_data_config(model.pretrained_cfg)
transform = timm.data.create_transform(**data_cfg)

# %%
test_data = Food101('data', split='test', transform=transform)
test_loader = DataLoader(test_data, batch_size=128, num_workers=4, pin_memory=True)

# %%
scripted_model = torch.jit.script(model)

# %%
scripted_model.save("models/levit_256.fb_dist_in1k/scripted.pt")

# %%
def test_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               accuracy_fn: torchmetrics.Metric):
    test_acc = 0
    model.eval()
    # Turn on inference context manager
    with torch.no_grad():
        for images, labels in tqdm(data_loader,
                                    total=len(data_loader),
                                    desc='Making predictions:'):
            # 1. Forward pass
            preds = model(images)

            # 2. Calculate accuracy
            test_acc += accuracy_fn(preds.argmax(dim=1), labels)

        # Adjust metrics and print out
        test_acc /= len(data_loader)
        print(f"Test accuracy: {test_acc:.2f}")
    return test_acc.cpu()

# %%
model_reloaded = torch.jit.load("models/levit_256.fb_dist_in1k/scripted.pt")

# %%
accuracy_fn = torchmetrics.Accuracy('multiclass', num_classes=101)
test_step(model_reloaded, test_loader, accuracy_fn)
# Out:
# Making predictions::   1%|          | 1/198 [00:02<06:37,  2.02s/it]/root/miniconda3/envs/seefood102/lib/python3.10/site-packages/torch/nn/modules/module.py:1501: UserWarning: operator() profile_node %247 : bool = prim::profile_ivalue(%training.49)
#  does not have profile information (Triggered internally at ../third_party/nvfuser/csrc/graph_fuser.cpp:104.)
#   return forward_call(*args, **kwargs)
# Making predictions:: 100%|██████████| 198/198 [02:41<00:00,  1.23it/s]
# Test accuracy: 0.65
# tensor(0.6523)
